# %%
import pandas as pd
from pathlib import Path

HISTORIC_PATH = Path("data/raw/historic")

seasons = sorted([
    p.name
    for p in HISTORIC_PATH.iterdir()
    if p.is_dir()
])

print("Seasons:", seasons)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3168/2718731955.py in <cell line: 0>()
#       6 seasons = sorted([
#       7     p.name
# ----> 8     for p in HISTORIC_PATH.iterdir()
#       9     if p.is_dir()
#      10 ])
#
# /usr/lib/python3.12/pathlib.py in iterdir(self)
#    1054         special entries '.' and '..' are not included.
#    1055         """
# -> 1056         for name in os.listdir(self):
#    1057             yield self._make_child_relpath(name)
#    1058
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/historic'

# %%
from google.colab import drive
drive.mount('/content/drive')
